# %% [markdown]
# ### Leetcode_problem_no:

# %%
# input: [0,3,4,3,0,0,2]
# output: [3,4,3,2,0,0,0]

# %% [markdown]
# ### Naive approach
#
# - create array with all element zero with size input array size n
# - then replace in array

# %%
from typing import List

def move_zeros(nums : List[int]):
    a

# %% [markdown]
# ### Two pointer based approach
#
# - right pointer track non-zero element
# - left pointer track zero elements
# - left pointer locks in zero element then use right pointer find non-zero element then swap it
# - once right pointer reach end all zero element in array end up in right and side of array
#
# #### Timecomplexity - O(n)
# #### Spacecomplexity - O(1)
