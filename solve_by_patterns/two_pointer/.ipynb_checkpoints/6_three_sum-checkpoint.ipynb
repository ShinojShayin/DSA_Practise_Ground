# %% [markdown]
# ### Leetcode_problem_no: 15
# ### Difficulty: Medium

# %% [markdown]
# ## 3Sum
#
# Given an integer array nums, return all the triplets [nums[i], nums[j], nums[k]] such that i != j, i != k, and j != k, and nums[i] + nums[j] + nums[k] == 0.
#
# Notice that the solution set must not contain duplicate triplets.
#
# ### Example 1:
# Input: nums = [-1, 0, 1, 2, -1, -4]
#
# Output: [[-1, -1, 2], [-1, 0, 1]]
#
# Explanation:
# ```text
# nums[0] + nums[1] + nums[2] = (-1) + 0 + 1 = 0.
# nums[1] + nums[2] + nums[4] = 0 + 1 + (-1) = 0.
# nums[0] + nums[3] + nums[4] = (-1) + 2 + (-1) = 0.
# ```
#
# The distinct triplets are `[-1, 0, 1]` and `[-1, -1, 2]`.
# Notice that the order of the output and the order of the triplets does not matter.
#
# ### Example 2:
# **Input:** `nums = [0, 1, 1]`
# **Output:** `[]`
# **Explanation:[-1, 0, 1, 2, -1, -4] The only possible triplet does not sum up to 0.
#
# ### Example 3:
# **Input:** `nums = [0, 0, 0]`
# **Output:** `[[0, 0, 0]]`
# **Explanation:** The only possible triplet sums up to 0.
#
# ### Constraints:
# * `3 <= nums.length <= 3000`
# * `-10^5 <= nums[i] <= 10^5`

# %%
# starter code

class Solution:
    def threeSum(self, nums: list[int]) -> list[list[int]]:

# %%
def threeSum(nums: list[int]) -> list[list[int]]:
    ary_len = len(nums)
    result = []

    nums.sort()

    for i in range(ary_len-2):
        
        if i > 0 and nums[i] == nums[(i - 1)]:
            continue

        for j in range(i+1, ary_len-1):
            
            if j > i+1 and nums[j] == nums[j-1]:
                continue

            for k in range(j+1, ary_len):

                if k > k+1 and nums[j] == nums[k-1]:
                    continue

                if nums[i] + nums[j] + nums[k] == 0:
                    result.append([nums[i] , nums[j] , nums[k]])

    return result

# %%
# Expected output : [[-1, -1, 2], [-1, 0, 1]]

input = [-1, 0, 1, 2, -1, -4]

threeSum(input)
# Out:
# []

# %%
# All Zeros
# Expected Output: [[0, 0, 0]]

input = [0, 0, 0, 0]

# %%
# Output: []

input = [1, 2, 3, 4, 5]

# %%
# Heavy Duplicates with Valid Triplets
# Output: [[-2, 0, 2]]

input = [-2, 0, 0, 2, 2, -2]

# %%
# Minimum Length Input
# Output: [[-1, 0, 1]]

input = [-1, 0, 1]

# %%
# Multiple Valid Triplets with Negatives
# Output: [[-4, 1, 3], [-4, 2, 2], [-2, -1, 3], [-2, 0, 2], [-2, 1, 1], [-1, -1, 0]]

input = [-4, -2, -2, -1, 0, 1, 2, 2, 3]

# %%
 # Output: [[-2, -1, 3], [-2, 0, 2], [-1, 0, 1]]

input = [-2, -1, 0, 1, 2, 3]
